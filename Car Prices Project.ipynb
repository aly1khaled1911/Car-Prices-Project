# %%
import pandas as pd

# %%
df=pd.read_csv('carprices.csv')

# %%
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
import matplotlib.pyplot as plt

# %%
plt.xlabel('age')
plt.ylabel('sell price')
plt.scatter(df['Age(yrs)'],df['Sell Price($)'],marker='x')
plt.show()

# %%
plt.xlabel('age')
plt.ylabel('sell price')
plt.scatter(df['Mileage'],df['Sell Price($)'],marker='x')
plt.show()

# %%
df['Mileage'].max()
# Out:
# 91000

# %%
df['Mileage']=df.Mileage/91000

# %%
df
# Out:
#      Mileage  Age(yrs)  Sell Price($)
# 0   0.758242         6          18000
# 1   0.384615         3          34000
# 2   0.626374         5          26100
# 3   0.247253         2          40000
# 4   0.505495         4          31500
# 5   0.648352         5          26750
# 6   0.571429         5          32000
# 7   0.791209         6          19300
# 8   1.000000         8          12000
# 9   0.736264         6          22000
# 10  0.912088         7          18700
# 11  0.868132         7          19500
# 12  0.648352         5          26000
# 13  0.645934         4          27500
# 14  0.906044         7          19400
# 15  0.279121         3          35000
# 16  0.307692         2          35500
# 17  0.758242         5          19700
# 18  0.962637         8          12800
# 19  0.571429         5          28200

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(df.drop('Sell Price($)',axis='columns'),df['Sell Price($)'],test_size=0.25)

# %%
xtrain
# Out:
#      Mileage  Age(yrs)
# 17  0.758242         5
# 10  0.912088         7
# 19  0.571429         5
# 0   0.758242         6
# 13  0.645934         4
# 6   0.571429         5
# 9   0.736264         6
# 11  0.868132         7
# 18  0.962637         8
# 2   0.626374         5
# 4   0.505495         4
# 12  0.648352         5
# 8   1.000000         8
# 16  0.307692         2
# 3   0.247253         2

# %%
model=LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
model.evaluate()
